# %% [markdown]
# Exploring Dataset
#
# Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import missingno as msno

# %% [markdown]
# # Reading the data

# %%
data= pd.read_csv(r"C:\Users\Abhijeet\ML Daily work\diabetes_classification\diabetes_012_health_indicators_BRFSS2015.csv")

# %%
data.head(10)
# Out:
#    Diabetes_012  HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  \
# 0             0       1         1          1   40       1       0
# 1             0       0         0          0   25       1       0
# 2             0       1         1          1   28       0       0
# 3             0       1         0          1   27       0       0
# 4             0       1         1          1   24       0       0
# 5             0       1         1          1   25       1       0
# 6             0       1         0          1   30       1       0
# 7             0       1         1          1   25       1       0
# 8             2       1         1          1   30       1       0
# 9             0       0         0          1   24       0       0
#
#    HeartDiseaseorAttack  PhysActivity  Fruits  ...  AnyHealthcare  \
# 0                     0             0       0  ...              1
# 1                     0             1       0  ...              0
# ...

# %% [markdown]
# ### Checking shape of the data

# %%
print('dataframe shape:', data.shape)
# Out:
# dataframe shape: (253680, 22)

# %% [markdown]
# ### Checking summery of the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253680 entries, 0 to 253679
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Diabetes_012          253680 non-null  int64
#  1   HighBP                253680 non-null  int64
#  2   HighChol              253680 non-null  int64
#  3   CholCheck             253680 non-null  int64
#  4   BMI                   253680 non-null  int64
#  5   Smoker                253680 non-null  int64
#  6   Stroke                253680 non-null  int64
#  7   HeartDiseaseorAttack  253680 non-null  int64
#  8   PhysActivity          253680 non-null  int64
#  9   Fruits                253680 non-null  int64
#  10  Veggies               253680 non-null  int64
#  11  HvyAlcoholConsump     253680 non-null  int64
#  12  AnyHealthcare         253680 non-null  int64
#  13  NoDocbcCost           253680 non-null  int64
# ...

# %%
data.describe()
# Out:
#         Diabetes_012         HighBP       HighChol      CholCheck  \
# count  253680.000000  253680.000000  253680.000000  253680.000000
# mean        0.296921       0.429001       0.424121       0.962670
# std         0.698160       0.494934       0.494210       0.189571
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       1.000000
# 50%         0.000000       0.000000       0.000000       1.000000
# 75%         0.000000       1.000000       1.000000       1.000000
# max         2.000000       1.000000       1.000000       1.000000
#
#                  BMI         Smoker         Stroke  HeartDiseaseorAttack  \
# count  253680.000000  253680.000000  253680.000000         253680.000000
# mean       28.382364       0.443169       0.040571              0.094186
# std         6.608694       0.496761       0.197294              0.292087
# min        12.000000       0.000000       0.000000              0.000000
# ...

# %% [markdown]
# # Checking Duplicated values

# %%
# removing Duplicate row
duplicate = data[data.duplicated().values]
print(len(duplicate))
# Out:
# 23899

# %% [markdown]
# There are 23899 duplicated rows , we have to drop these

# %%
# deleting duplicates rows from data set
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (229781, 22)

# %% [markdown]
# # Checking missing values

# %%
data.isnull().sum()
# Out:
# Diabetes_012            0
# HighBP                  0
# HighChol                0
# CholCheck               0
# BMI                     0
# Smoker                  0
# Stroke                  0
# HeartDiseaseorAttack    0
# PhysActivity            0
# Fruits                  0
# Veggies                 0
# HvyAlcoholConsump       0
# AnyHealthcare           0
# NoDocbcCost             0
# GenHlth                 0
# MentHlth                0
# PhysHlth                0
# DiffWalk                0
# Sex                     0
# Age                     0
# Education               0
# Income                  0
# dtype: int64

# %% [markdown]
# - here we can clearly see that no null values present in the data

# %%
# ploting heatmap for checking correlation
plt.figure(figsize= (17,18))
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Visulization

# %%
def diabetes_category(Diabetes_012):
    diabetes_dict = {
        0: 'No Diabetes',
        1: 'Diabetes',
        2: 'Prediabetes',
       
    }
    return diabetes_dict[Diabetes_012//1]



def HighBP_category(HighBP):
    HighBP_dict = {
        0: 'No High',
        1: 'High',      
    }
    return HighBP_dict[HighBP//1]

    
def HighChol_category(HighChol):
    HighChol_dict = {
        0: 'No High',
        1: 'High',      
    }
    return HighChol_dict[HighChol//1]


def BMI_category(BMI):
    if BMI < 18.5:
        return 'under-weight'
    elif BMI >= 18.5 and BMI <= 24.9:
        return 'normal-weight'
    elif BMI >= 24 and BMI <= 29.9:
        return 'over-weight'
    elif BMI > 30.0:
        return "obese"

data['cDiabetes'] = data['Diabetes_012'].apply(lambda x: "none")
data['cHighChol'] = data['HighChol'].apply(lambda x: "none")
data['cHighBP'] = data['HighBP'].apply(lambda x: "none")
data['cBMI'] = data['BMI'].apply(lambda x: "none")
for idx, row in data.iterrows():
    data.at[idx, 'cDiabetes'] = diabetes_category(row['Diabetes_012'])
    data.at[idx, 'cHighChol'] = HighChol_category(row['HighChol'])
    data.at[idx, 'cHighBP'] = HighBP_category(row['HighBP']) 
    data.at[idx, 'cBMI'] = BMI_category(row['BMI'])

by_Diabetes = data.groupby(by='cDiabetes').size()
print (by_Diabetes)
print ('-'*80)

by_HighChol = data.groupby(by='cHighChol').size()
print (by_HighChol)
print ('-'*80)

by_HighBP = data.groupby(by='cHighBP').size()
print (by_HighBP)
print ('-'*80)

by_BMI = data.groupby(by='cBMI').size()
print (by_BMI)
print ('-'*80)
# Out:
# cDiabetes
# Diabetes         4629
# No Diabetes    190055
# Prediabetes     35097
# dtype: int64
# --------------------------------------------------------------------------------
# cHighChol
# High       101508
# No High    128273
# dtype: int64
# --------------------------------------------------------------------------------
# cHighBP
# High       104422
# No High    125359
# dtype: int64
# --------------------------------------------------------------------------------
# cBMI
# normal-weight    58927
# obese            71437
# over-weight      82859
# under-weight      3053
# dtype: int64
# --------------------------------------------------------------------------------

# %% [markdown]
# To understand correlation between the input or the independent variables, I classified the Diabetes,HighBP, HighChol, BMI into specific categories.  Taking the BMI ranges from Medline Plus, I categorized the input samples into 'below-weight', 'normal-weight', 'over-weight' and 'obese'

# %%
variables = ['cDiabetes','cHighChol','cHighBP','cBMI','Smoker','Sex','Age']

# data distribution analysys
print('Data distribution analysys')
for v in variables:
    data = data.sort_values(by=[v])
    data[v].value_counts().plot(kind = 'bar')
    plt.title(v)
    plt.show()
# Out:
# Data distribution analysys

# %% [markdown]
# From the above data we can observe below
#
# - Input data contains No diabetes patients are higher
# - Majority of them are non-smokers
# - Majority of the samples are in age groups 9 and 10.
# - Majority of the samples are of females.
# - Overweighted and Obese peoples are maximum in this dataset.

# %% [markdown]
# # Creating independent and dependent variable

# %%
X =data.drop(['Diabetes_012','cDiabetes','cHighChol','cHighBP','cBMI'], axis=1)
y = data['Diabetes_012'].values

# %% [markdown]
# # Splitting data into train and test

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size = 0.3,random_state = 1)

# %%
X_train.shape
# Out:
# (160846, 21)

# %%
y_test.shape
# Out:
# (68935,)

# %%
from sklearn.preprocessing import StandardScaler
SS = StandardScaler()
X_train = SS.fit_transform(X_train)
X_test = SS.transform(X_test)

# %% [markdown]
# # K-Nearest Neighbor(KNN) Model

# %%
#Fitting K-NN classifier to the training set  
from sklearn.neighbors import KNeighborsClassifier  
KNclassifier= KNeighborsClassifier(n_neighbors=5, metric='minkowski', p=2 )  
KNclassifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
#Predicting the test set result  
ypred= KNclassifier.predict(X_test)

# %%
ypred
# Out:
# array([0, 0, 0, ..., 2, 0, 0], dtype=int64)

# %%
#Creating the Confusion matrix  
from sklearn.metrics import confusion_matrix,classification_report,plot_confusion_matrix,accuracy_score
CM= confusion_matrix(y_test, ypred)
AC = accuracy_score(y_test,ypred)
plot_confusion_matrix(KNclassifier,X_test, y_test)
# Out:
# C:\Users\Abhijeet\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
print(CM)
# Out:
# [[54009    26  2868]
#  [ 1192     5   197]
#  [ 8442    35  2161]]

# %%
print(classification_report(y_test,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.95      0.90     56903
#            1       0.08      0.00      0.01      1394
#            2       0.41      0.20      0.27     10638
#
#     accuracy                           0.81     68935
#    macro avg       0.45      0.39      0.39     68935
# weighted avg       0.77      0.81      0.78     68935

# %% [markdown]
# # Training the Naive Bayes model

# %%
# Training the Naive Bayes model on the Training set
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
# predicting the test set results
y_pred = classifier.predict(X_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 2, 0], dtype=int64)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix, accuracy_score, plot_confusion_matrix, classification_report
AC = accuracy_score(y_test,y_pred)
CM = confusion_matrix(y_test, y_pred)
plot_confusion_matrix(classifier, X_test, y_test)
# Out:
# C:\Users\Abhijeet\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.79      0.84     56903
#            1       0.03      0.01      0.01      1394
#            2       0.33      0.57      0.42     10638
#
#     accuracy                           0.74     68935
#    macro avg       0.42      0.46      0.43     68935
# weighted avg       0.79      0.74      0.76     68935

# %% [markdown]
# # Logistic Regression

# %%
# Training the logistic regression model on the Training set
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state=0)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
# predicting the test set results
y_pred = classifier.predict(X_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
y_test
# Out:
# array([0, 0, 0, ..., 2, 2, 0], dtype=int64)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix, accuracy_score, plot_confusion_matrix, classification_report
ac = accuracy_score(y_test,y_pred)
cm = confusion_matrix(y_test, y_pred)
plot_confusion_matrix(classifier, X_test, y_test)
# Out:
# C:\Users\Abhijeet\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.98      0.91     56903
#            1       0.00      0.00      0.00      1394
#            2       0.54      0.17      0.26     10638
#
#     accuracy                           0.83     68935
#    macro avg       0.46      0.38      0.39     68935
# weighted avg       0.78      0.83      0.79     68935
# C:\Users\Abhijeet\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
